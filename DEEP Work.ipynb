# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

complete_df = pd.read_csv("teamBoxScore.csv")
complete_df.head()
predictor_stats = complete_df[["teamAbbr","gmDate","teamRslt","seasTyp","teamEDiff","teamASST%","team2P%","team3P%","teamFT%","opptTO%"]]
predictor_stats["Q4Diff"] = complete_df["teamPTS4"] - complete_df["opptPTS4"]
predictor_stats
# Out:
# /Users/ankitpatel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#       teamAbbr      gmDate teamRslt  seasTyp  teamEDiff  teamASST%  team2P%  \
# 0          WAS  2012-10-30     Loss  Regular   -11.2435    81.2500   0.4138
# 1          CLE  2012-10-30      Win  Regular    11.2435    61.1111   0.4915
# 2          BOS  2012-10-30     Loss  Regular   -13.6866    61.5385   0.5323
# 3          MIA  2012-10-30      Win  Regular    13.6866    58.1395   0.5556
# 4          DAL  2012-10-30      Win  Regular     8.7356    55.0000   0.5000
# ...        ...         ...      ...      ...        ...        ...      ...
# ...
